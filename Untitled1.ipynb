# %%
import logging
import os
import time
from urllib.parse import urlparse
from getpass import getpass

import treq
from scrapy.crawler import CrawlerProcess
from scrapy.linkextractors import LinkExtractor
from scrapy.spiders import CrawlSpider, Rule
from slugify import slugify

# %%
DOCS_URL = "https://docs.fastht.ml/"
logger = logging.getLogger(__name__)

os.environ['JINA_API_KEY'] = getpass('Enter your JINA API Key: ')
# "jina_32c6bf4c80324eda8b0af06264877b92wuWhwoeK-I_3kowa5gDXaSydK0_i"
# NOTE: 200 requests per min w/ Jina API key
# Out:
# Enter your JINA API Key:  ········

# %%
def urljoin(*args):
  """
  Joins given arguments into an url. Trailing but not leading slashes are
  stripped for each argument.
  """

  return "/".join(map(lambda x: str(x).rstrip('/'), args))

# %%
class MarkdownPipeline:

  def create_directory_from_url_with_slug(self, url):
    parsed_url = urlparse(url)
    path_segments = parsed_url.path.strip('/').split('/')
    directory_path = './docs/' + self.collection
    for segment in path_segments[:-1]:
      directory_path = os.path.join(directory_path, segment)
      os.makedirs(directory_path, exist_ok=True)
    filename = slugify(path_segments[-1])
    return os.path.join(directory_path, filename)

  def open_spider(self, spider):
    self.collection = spider.domain.title().replace('.', '')
    os.makedirs(f'./docs/{self.collection}', exist_ok=True)

  async def process_item(self, item, spider):
    response = await treq.get('https://r.jina.ai/' + item.get('url'),
                              headers={
                                  'Content-Type':
                                  'text/plain',
                                  "Authorization":
                                  f"Bearer {os.environ['JINA_API_KEY']}"
                              })

    content = await response.text()
    url = item.get('url')

    directory = self.create_directory_from_url_with_slug(url)

    with open(directory + '.md', 'w') as f:
      f.write(content)

    return item

  def close_spider(self, spider):
    self.client.close()

# %%
class PagingIncremental(CrawlSpider):
  name = "docs"
  custom_settings = {
      'DOWNLOAD_DELAY': '0',
      'FEED_EXPORT_ENCODING': 'utf-8',
      'DEPTH_LIMIT': '0',
      'AUTOTHROTTLE_ENABLED': 'True',
      'AUTOTHROTTLE_START_DELAY': '1',
      'AUTOTHROTTLE_MAX_DELAY': '3',
      "AUTOTHROTTLE_TARGET_CONCURRENCY": '1'
  }
  rules = (Rule(LinkExtractor(allow=r""), callback='parse', follow=True), )

  def __init__(self, url, *args, **kwargs):
    super().__init__(*args, **kwargs)
    # Visit all found sublinks
    print(url)
    self.domain = urlparse(url).hostname
    self.domain_name = self.domain.split('.')[1]
    self.allowed_domains = [self.domain]

    self.start_urls = [url]

  def parse(self, response):

    item = {}
    item["url"] = response.url
    time.sleep(.1)
    yield item


def process_docs(url):
  process = CrawlerProcess({
      'USER_AGENT': 'Mozilla/5.0',
      'ITEM_PIPELINES': {
          '__main__.MarkdownPipeline': 1,
      },
  })
    
  process.crawl(PagingIncremental, url=url)
  process.start(stop_after_crawl=True)

# %%
if __name__ == "__main__":
  process_docs(DOCS_URL)
# Out:
# 2024-08-30 22:03:17 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: scrapybot)
# 2024-08-30 22:03:17 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.12.7, cssselect 1.2.0, parsel 1.9.1, w3lib 2.2.1, Twisted 24.7.0, Python 3.11.9 | packaged by conda-forge | (main, Apr 19 2024, 18:36:13) [GCC 12.3.0], pyOpenSSL 24.2.1 (OpenSSL 3.3.1 4 Jun 2024), cryptography 43.0.0, Platform Linux-5.15.153.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# 2024-08-30 22:03:17 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-08-30 22:03:17 [py.warnings] WARNING: /home/amrit/miniforge3/envs/llmdev/lib/python3.11/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-08-30 22:03:17 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2024-08-30 22:03:17 [scrapy.extensions.telnet] INFO: Telnet Password: 8b16eb2e35f438ba
# 2024-08-30 22:03:18 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.throttle.AutoThrottle']
# 2024-08-30 22:03:18 [scrapy.crawler] INFO: Overridden settings:
# {'AUTOTHROTTLE_ENABLED': 'True',
#  'AUTOTHROTTLE_MAX_DELAY': '3',
#  'AUTOTHROTTLE_START_DELAY': '1',
#  'AUTOTHROTTLE_TARGET_CONCURRENCY': '1',
#  'DEPTH_LIMIT': '0',
#  'DOWNLOAD_DELAY': '0',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'USER_AGENT': 'Mozilla/5.0'}
# 2024-08-30 22:03:18 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-08-30 22:03:18 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-08-30 22:03:18 [scrapy.middleware] INFO: Enabled item pipelines:
# ['__main__.MarkdownPipeline']
# 2024-08-30 22:03:18 [scrapy.core.engine] INFO: Spider opened
# 2024-08-30 22:03:18 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-08-30 22:03:18 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# https://docs.fastht.ml/
# 2024-08-30 22:03:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://docs.fastht.ml/> (referer: None)
# 2024-08-30 22:03:18 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'fastht.ml': <GET https://fastht.ml>
# 2024-08-30 22:03:18 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:18 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'about.fastht.ml': <GET https://about.fastht.ml>
# 2024-08-30 22:03:18 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://about.fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:18 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'github.com': <GET https://github.com/answerdotai/fasthtml>
# 2024-08-30 22:03:18 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/answerdotai/fasthtml> before it reached the scheduler.
# 2024-08-30 22:03:18 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'x.com': <GET https://x.com/answerdotai>
# 2024-08-30 22:03:18 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://x.com/answerdotai> before it reached the scheduler.
# 2024-08-30 22:03:18 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://docs.fastht.ml/#usage> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2024-08-30 22:03:18 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/issues/new> before it reached the scheduler.
# 2024-08-30 22:03:18 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://about.fastht.ml/> before it reached the scheduler.
# 2024-08-30 22:03:18 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/examples/adv_app.py> before it reached the scheduler.
# 2024-08-30 22:03:18 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml-example> before it reached the scheduler.
# 2024-08-30 22:03:18 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml> before it reached the scheduler.
# 2024-08-30 22:03:18 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'gallery.fastht.ml': <GET https://gallery.fastht.ml>
# 2024-08-30 22:03:18 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://gallery.fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:18 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'isaac-flath.github.io': <GET https://isaac-flath.github.io/website/posts/boots/FasthtmlTutorial.html>
# 2024-08-30 22:03:18 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://isaac-flath.github.io/website/posts/boots/FasthtmlTutorial.html> before it reached the scheduler.
# 2024-08-30 22:03:18 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'discord.gg': <GET https://discord.gg/qcXvcxMhdP>
# 2024-08-30 22:03:18 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://discord.gg/qcXvcxMhdP> before it reached the scheduler.
# 2024-08-30 22:03:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://docs.fastht.ml/index.html> (referer: https://docs.fastht.ml/)
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://about.fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/answerdotai/fasthtml> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://x.com/answerdotai> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/issues/new> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://about.fastht.ml/> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/examples/adv_app.py> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml-example> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://gallery.fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://isaac-flath.github.io/website/posts/boots/FasthtmlTutorial.html> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://discord.gg/qcXvcxMhdP> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://docs.fastht.ml/#installation> (referer: https://docs.fastht.ml/)
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://about.fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/answerdotai/fasthtml> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://x.com/answerdotai> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/issues/new> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://about.fastht.ml/> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/examples/adv_app.py> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml-example> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://gallery.fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://isaac-flath.github.io/website/posts/boots/FasthtmlTutorial.html> before it reached the scheduler.
# 2024-08-30 22:03:20 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://discord.gg/qcXvcxMhdP> before it reached the scheduler.
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://docs.fastht.ml/api/fastapp.html> (referer: https://docs.fastht.ml/)
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://about.fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/answerdotai/fasthtml> before it reached the scheduler.
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://x.com/answerdotai> before it reached the scheduler.
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/issues/new> before it reached the scheduler.
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/fastapp.py#L38> before it reached the scheduler.
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/fastapp.py#L99> before it reached the scheduler.
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/fastapp.py#L98> before it reached the scheduler.
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://docs.fastht.ml/api/cli.html> (referer: https://docs.fastht.ml/)
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://about.fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/answerdotai/fasthtml> before it reached the scheduler.
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://x.com/answerdotai> before it reached the scheduler.
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/issues/new> before it reached the scheduler.
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/cli.py#L15> before it reached the scheduler.
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/cli.py#L33> before it reached the scheduler.
# 2024-08-30 22:03:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/>
# {'url': 'https://docs.fastht.ml/'}
# 2024-08-30 22:03:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://docs.fastht.ml/api/oauth.html> (referer: https://docs.fastht.ml/)
# 2024-08-30 22:03:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/index.html>
# {'url': 'https://docs.fastht.ml/index.html'}
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://docs.fastht.ml/api/pico.html> (referer: https://docs.fastht.ml/)
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://about.fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/answerdotai/fasthtml> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://x.com/answerdotai> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/issues/new> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/oauth.py#L22> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/oauth.py#L36> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/oauth.py#L48> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/oauth.py#L63> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/oauth.py#L91> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/oauth.py#L98> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/oauth.py#L106> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/oauth.py#L116> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/oauth.py#L123> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/oauth.py#L130> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://about.fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/answerdotai/fasthtml> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://x.com/answerdotai> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/issues/new> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/pico.py#L30> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/pico.py#L49> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/pico.py#L57> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/pico.py#L63> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/pico.py#L69> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/pico.py#L76> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/pico.py#L83> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/pico.py#L88> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://docs.fastht.ml/api/js.html> (referer: https://docs.fastht.ml/)
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://about.fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/answerdotai/fasthtml> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://x.com/answerdotai> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/issues/new> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/js.py#L15> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/js.py#L22> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/js.py#L35> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/js.py#L43> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/js.py#L58> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/js.py#L82> before it reached the scheduler.
# 2024-08-30 22:03:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://docs.fastht.ml/api/xtend.html> (referer: https://docs.fastht.ml/)
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://about.fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/answerdotai/fasthtml> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://x.com/answerdotai> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/issues/new> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L25> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L31> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'answerdotai.github.io': <GET https://answerdotai.github.io/fasthtml/api/components.html#ft_hx>
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://answerdotai.github.io/fasthtml/api/components.html#ft_hx> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L37> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L43> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L49> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://answerdotai.github.io/fasthtml/api/xtend.html#hidden> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L59> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L65> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L70> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L76> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L82> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L88> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L96> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L105> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L113> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L120> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L125> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L131> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L136> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L143> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L150> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L155> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L178> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L184> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://answerdotai.github.io/fasthtml/api/xtend.html#script> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/xtend.py#L192> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://docs.fastht.ml/api/components.html> (referer: https://docs.fastht.ml/)
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://about.fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/answerdotai/fasthtml> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://x.com/answerdotai> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/issues/new> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/components.py#L34> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/components.py#L46> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/components.py#L55> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/components.py#L65> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/components.py#L85> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/components.py#L109> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/components.py#L116> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/components.py#L122> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/components.py#L136> before it reached the scheduler.
# 2024-08-30 22:03:23 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/components.py#L144> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://docs.fastht.ml/api/core.html> (referer: https://docs.fastht.ml/)
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://about.fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/answerdotai/fasthtml> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://x.com/answerdotai> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/issues/new> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'nbdev.fast.ai': <GET https://nbdev.fast.ai/>
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://nbdev.fast.ai/> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://answerdotai.github.io/fasthtml/api/core.html#date> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L40> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L45> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L62> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/api/cli.html>
# {'url': 'https://docs.fastht.ml/api/cli.html'}
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L72> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L108> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L126> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L184> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L194> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L254> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L260> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L264> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L275> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L283> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L318> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L362> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L388> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L415> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L444> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L487> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L507> before it reached the scheduler.
# 2024-08-30 22:03:24 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/core.py#L529> before it reached the scheduler.
# ...
# 2024-08-30 22:03:37 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'testdriven.io': <GET https://testdriven.io/blog/flask-stripe-tutorial/>
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://testdriven.io/blog/flask-stripe-tutorial/> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml-example/blob/main/image_app_session_credits/main.py> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'starlette.io': <GET https://starlette.io/docs/>
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://starlette.io/docs/> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'daisyui.com': <GET https://daisyui.com/components/chat/>
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://daisyui.com/components/chat/> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'h2x.answer.ai': <GET https://h2x.answer.ai/>
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://h2x.answer.ai/> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'claudette.answer.ai': <GET https://claudette.answer.ai/>
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://claudette.answer.ai/> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml-example/tree/main/02_chatbot> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://en.wikipedia.org/wiki/Conway's_Game_of_Life> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/bigskysoftware/htmx-extensions/blob/main/src/ws/README.md> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'game-of-life-production-ed7f.up.railway.app': <GET https://game-of-life-production-ed7f.up.railway.app/>
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://game-of-life-production-ed7f.up.railway.app/> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://answerdotai.github.io/fasthtml/api/xtend.html#script> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://answerdotai.github.io/fasthtml/api/xtend.html#style> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/blob/main/fasthtml/js.py> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'marked.js.org': <GET https://marked.js.org/>
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://marked.js.org/> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml-example/tree/main/ai_pictionary> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml-example/tree/main/doodle> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/chr15m/DoodleCSS> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml-hf> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml-example/blob/main/deploying-to-pythonanywhere.md> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://docs.railway.app/guides/cli> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://docs.railway.app/guides/variables> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'replit.com': <GET https://replit.com/@johnowhitaker/FastHTML-Example>
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://replit.com/@johnowhitaker/FastHTML-Example> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml-example> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://www.youtube.com/@howardjeremyp> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://docs.fastht.ml/tutorials/index.html> (referer: https://docs.fastht.ml/)
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://about.fastht.ml> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/answerdotai/fasthtml> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://x.com/answerdotai> before it reached the scheduler.
# 2024-08-30 22:03:37 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://github.com/AnswerDotAI/fasthtml/issues/new> before it reached the scheduler.
# 2024-08-30 22:03:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://docs.fastht.ml/tutorials/by_example.html.md> (referer: https://docs.fastht.ml/tutorials/by_example.html)
# 2024-08-30 22:03:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://docs.fastht.ml/cdn-cgi/l/email-protection> (referer: https://docs.fastht.ml/tutorials/by_example.html)
# 2024-08-30 22:03:38 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.cloudflare.com': <GET https://www.cloudflare.com/sign-up?utm_source=email_protection>
# 2024-08-30 22:03:38 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://www.cloudflare.com/sign-up?utm_source=email_protection> before it reached the scheduler.
# 2024-08-30 22:03:38 [scrapy.downloadermiddlewares.offsite] DEBUG: Filtered offsite request to 'support.cloudflare.com': <GET https://support.cloudflare.com/hc/en-us/articles/200170016-What-is-Email-Address-Obfuscation->
# 2024-08-30 22:03:38 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://support.cloudflare.com/hc/en-us/articles/200170016-What-is-Email-Address-Obfuscation-> before it reached the scheduler.
# 2024-08-30 22:03:38 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://support.cloudflare.com/hc/en-us/categories/200275218-Getting-Started> before it reached the scheduler.
# 2024-08-30 22:03:38 [scrapy.core.engine] DEBUG: Signal handler scrapy.downloadermiddlewares.offsite.OffsiteMiddleware.request_scheduled dropped request <GET https://www.cloudflare.com/5xx-error-landing> before it reached the scheduler.
# 2024-08-30 22:03:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/api/oauth.html.md>
# {'url': 'https://docs.fastht.ml/api/oauth.html.md'}
# 2024-08-30 22:03:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://docs.fastht.ml/tutorials/index.md> (referer: https://docs.fastht.ml/tutorials/index.html)
# 2024-08-30 22:03:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/explains/faq.html.md>
# {'url': 'https://docs.fastht.ml/explains/faq.html.md'}
# 2024-08-30 22:03:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/tutorials/index.html>
# {'url': 'https://docs.fastht.ml/tutorials/index.html'}
# 2024-08-30 22:03:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/api/xtend.html.md>
# {'url': 'https://docs.fastht.ml/api/xtend.html.md'}
# 2024-08-30 22:03:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/tutorials/quickstart_for_web_devs.html.md>
# {'url': 'https://docs.fastht.ml/tutorials/quickstart_for_web_devs.html.md'}
# 2024-08-30 22:03:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/api/core.html.md>
# {'url': 'https://docs.fastht.ml/api/core.html.md'}
# 2024-08-30 22:03:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/tutorials/by_example.html.md>
# {'url': 'https://docs.fastht.ml/tutorials/by_example.html.md'}
# 2024-08-30 22:03:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/explains/routes.html.md>
# {'url': 'https://docs.fastht.ml/explains/routes.html.md'}
# 2024-08-30 22:03:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/tutorials/index.md>
# {'url': 'https://docs.fastht.ml/tutorials/index.md'}
# 2024-08-30 22:03:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/ref/defining_xt_component.html>
# {'url': 'https://docs.fastht.ml/ref/defining_xt_component.html'}
# 2024-08-30 22:04:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/tutorials/by_example.html>
# {'url': 'https://docs.fastht.ml/tutorials/by_example.html'}
# 2024-08-30 22:04:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/cdn-cgi/l/email-protection>
# {'url': 'https://docs.fastht.ml/cdn-cgi/l/email-protection'}
# 2024-08-30 22:04:18 [scrapy.extensions.logstats] INFO: Crawled 44 pages (at 44 pages/min), scraped 34 items (at 34 items/min)
# 2024-08-30 22:04:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/ref/live_reload.html>
# {'url': 'https://docs.fastht.ml/ref/live_reload.html'}
# 2024-08-30 22:04:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/ref/defining_xt_component.md>
# {'url': 'https://docs.fastht.ml/ref/defining_xt_component.md'}
# 2024-08-30 22:04:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/explains/routes.html>
# {'url': 'https://docs.fastht.ml/explains/routes.html'}
# 2024-08-30 22:05:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/api/cli.html.md>
# {'url': 'https://docs.fastht.ml/api/cli.html.md'}
# 2024-08-30 22:05:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/api/oauth.html>
# {'url': 'https://docs.fastht.ml/api/oauth.html'}
# 2024-08-30 22:05:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/tutorials/tutorial_for_web_devs.html.md>
# {'url': 'https://docs.fastht.ml/tutorials/tutorial_for_web_devs.html.md'}
# 2024-08-30 22:05:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/explains/oauth.html>
# {'url': 'https://docs.fastht.ml/explains/oauth.html'}
# 2024-08-30 22:05:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/tutorials/e2e.html.md>
# {'url': 'https://docs.fastht.ml/tutorials/e2e.html.md'}
# 2024-08-30 22:05:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://docs.fastht.ml/explains/explaining_xt_components.html.md>
# {'url': 'https://docs.fastht.ml/explains/explaining_xt_components.html.md'}
# 2024-08-30 22:05:15 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-08-30 22:05:15 [scrapy.core.engine] ERROR: Scraper close failure
# Traceback (most recent call last):
#   File "/home/amrit/miniforge3/envs/llmdev/lib/python3.11/site-packages/twisted/internet/defer.py", line 1074, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/tmp/ipykernel_61867/4100577622.py", line 37, in close_spider
#     self.client.close()
# AttributeError: 'MarkdownPipeline' object has no attribute 'client'
# 2024-08-30 22:05:15 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 11669,
#  'downloader/request_count': 44,
#  'downloader/request_method_count/GET': 44,
#  'downloader/response_bytes': 409881,
#  'downloader/response_count': 44,
#  'downloader/response_status_count/200': 44,
#  'dupefilter/filtered': 2533,
#  'elapsed_time_seconds': 117.392787,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 8, 30, 10, 5, 15, 479302, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 1613942,
#  'httpcompression/response_count': 43,
#  'item_scraped_count': 43,
#  'log_count/DEBUG': 451,
#  'log_count/ERROR': 1,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'memusage/max': 179744768,
#  'memusage/startup': 130506752,
#  'offsite/domains': 39,
#  'offsite/filtered': 323,
#  'request_depth_max': 3,
#  'response_received_count': 44,
#  'scheduler/dequeued': 44,
#  'scheduler/dequeued/memory': 44,
#  'scheduler/enqueued': 44,
#  'scheduler/enqueued/memory': 44,
#  'start_time': datetime.datetime(2024, 8, 30, 10, 3, 18, 86515, tzinfo=datetime.timezone.utc)}
# 2024-08-30 22:05:15 [scrapy.core.engine] INFO: Spider closed (finished)
